# %%
# uncomment if you haven't installed the package
# !pip install -e "git+https://github.com/daffarobani/smt-explainability.git"#egg=smt-ex
# !pip install sobolsampling

# %%
from smt.surrogate_models import KRG
from smt_ex.problems import MixedCantileverBeam
from smt.design_space import (
    DesignSpace,
    FloatVariable,
    CategoricalVariable,
)
from smt.surrogate_models import (
    KPLS,
    MixIntKernelType,
    MixHrcKernelType,
)
from smt.applications.mixed_integer import MixedIntegerKrigingModel

from smt_ex.pdp.partial_dependence_display import PartialDependenceDisplay
from smt_ex.pdp.pd_feature_importance_display import PDFeatureImportanceDisplay
from smt_ex.pdp.pd_interaction_display import PDFeatureInteractionDisplay

from sklearn.metrics import mean_squared_error
import numpy as np
import time

# %%
ndoe = 200
n_train = int(0.8 * ndoe)
fun = MixedCantileverBeam()
# Name of the features
feature_names = [r'$\tilde{I}$', r'$L$', r'$S$']
# Index for categorical features
categorical_feature_indices = [0]
# Design space
ds = DesignSpace([
    CategoricalVariable(values=[str(i + 1) for i in range(12)]),
    FloatVariable(10.0, 20.0),
    FloatVariable(1.0, 2.0),
])
# create mapping for the categories
categories_map = dict()
inverse_categories_map = dict()
for feature_idx in categorical_feature_indices:
    categories_map[feature_idx] = {
        i: value for i, value in enumerate(ds._design_variables[feature_idx].values)
    }
    inverse_categories_map[feature_idx] = {
        value: i for i, value in enumerate(ds._design_variables[feature_idx].values)
    }

X = fun.sample(ndoe)
y = fun(X)

X_tr, y_tr = X[:n_train, :], y[:n_train]
X_te, y_te = X[n_train:, :], y[n_train:]

class GroundTruthModel:
    def predict_values(self, X):
        return fun(X)
    
gtm = GroundTruthModel()

# %%
sm = MixedIntegerKrigingModel(
    surrogate=KPLS(
        design_space=ds,
        categorical_kernel=MixIntKernelType.HOMO_HSPHERE,
        hierarchical_kernel=MixHrcKernelType.ARC_KERNEL,
        theta0=np.array([4.43799547e-04, 4.39993134e-01, 1.59631650e+00]),
        corr="squar_exp",
        n_start=1,
        cat_kernel_comps=[2],
        n_comp=2,
        print_global=False,
        ),
    )

start_time = time.time()
sm.set_training_values(X_tr, np.array(y_tr))
sm.train()
print("run time (s):", time.time() - start_time)

print("Surrogate model")
y_pred = sm.predict_values(X_te)
rmse = mean_squared_error(y_te, y_pred, squared=False)
rrmse = rmse / y_te.mean()
print(f"RMSE: {rmse:.4f}")
print(f"rRMSE: {rrmse:.4f}")
# Out:
# /Users/muhammaddaffarobani/miniconda3/envs/smt_ex_39/lib/python3.9/site-packages/smt/applications/mixed_integer.py:208: UserWarning: TNC not available yet for mixed integer handling. Switching to Cobyla
#   warnings.warn(
# run time (s): 36.29198503494263
# Surrogate model
# RMSE: 0.0001
# rRMSE: 0.1082
# /Users/muhammaddaffarobani/miniconda3/envs/smt_ex_39/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# %%
model = gtm

gt_pdd_importance = PDFeatureImportanceDisplay.from_surrogate_model(
    model, X_tr, feature_names=feature_names, categorical_feature_indices=categorical_feature_indices
)
gt_pdd_importance.plot(figsize=[8, 4])

gt_pdd_importance.plot(figsize=[8, 4]).savefig('test.png')

# %%
gt_pdd_importance.feature_importances
# Out:
# [0.0003886629364933791, 0.0005240018267814041, 0.0003973809386563222]

# %%
model = sm

sm_pdd_importance = PDFeatureImportanceDisplay.from_surrogate_model(
    model, X_tr, feature_names=feature_names, categorical_feature_indices=categorical_feature_indices
)
sm_pdd_importance.plot(figsize=[8, 4])

# %%
# %%time
model = gtm

features = [i for i in range(X_tr.shape[1])]

gt_pdd = PartialDependenceDisplay.from_surrogate_model(
    model, 
    X_tr, 
    features, 
    categorical_feature_indices=categorical_feature_indices, 
    feature_names=feature_names,
    grid_resolution=20,
    kind='both',
    categories_map=categories_map,
    )

gt_pdd_plot_1d = gt_pdd.plot(centered=True)
gt_pdd_plot_1d
# Out:
# CPU times: user 622 ms, sys: 934 ms, total: 1.56 s
# Wall time: 239 ms

# %%
# %%time
model = sm

features = [i for i in range(X_tr.shape[1])]

pdd = PartialDependenceDisplay.from_surrogate_model(
    model, 
    X_tr, 
    features, 
    categorical_feature_indices=categorical_feature_indices, 
    feature_names=feature_names,
    grid_resolution=20,
    kind='both',
    categories_map=categories_map,
    )

pdd_plot_1d = pdd.plot(centered=True)
pdd_plot_1d
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5
#
# File ~/Documents/personal_research/smt-explainability/smt_ex/pdp/partial_dependence_display.py:33, in PartialDependenceDisplay.from_surrogate_model(cls, model, x, features, sample_weight, categorical_feature_indices, feature_names, percentiles, grid_resolution, kind, ratio_samples, categories_map)
#      17 @classmethod
#      18 def from_surrogate_model(
#      19     cls,
#    (...)
#      31     categories_map=None,
#      32 ):
# ---> 33     pd_results = partial_dependence(
#      34         model,
#      35         x,
#      36         features,
#      37         sample_weight=sample_weight,
#      38         categorical_feature_indices=categorical_feature_indices,
#      39         percentiles=percentiles,
#      40         grid_resolution=grid_resolution,
#      41         kind=kind,
#      42         ratio_samples=ratio_samples,
#      43         categories_map=categories_map,
#      44     )
#      46     target_features = set()
#      47     for feature in features:
#
# File ~/Documents/personal_research/smt-explainability/smt_ex/pdp/partial_dependence.py:159, in partial_dependence(model, x, features, sample_weight, categorical_feature_indices, percentiles, grid_resolution, kind, method, ratio_samples, categories_map)
#     149 grid_cartesian, grid_values = grid_from_x(
#     150     x,
#     151     feature,
#    (...)
#     155     method,
#     156 )
#     158 # predictions
# --> 159 averaged_predictions, predictions = _partial_dependence_brute(
#     160     model,
#     161     grid_cartesian,
#     162     grid_values,
#     163     feature,
#     164     x,
#     165     method,
#     166     sample_weight,
#     167     ratio_samples,
#     168 )
#     170 # storing values
#     171 pdp_result = {"grid_values": grid_values}
#
# File ~/Documents/personal_research/smt-explainability/smt_ex/pdp/partial_dependence.py:76, in _partial_dependence_brute(model, grid_cartesian, grid_values, features, x, method, sample_weight, ratio_samples)
#      74     x_eval[:, feature] = new_values[i]
#      75 try:
# ---> 76     pred = model.predict_values(x_eval)
#      77 except AttributeError:
#      78     pred = model.predict(x_eval)
#
# File ~/miniconda3/envs/smt_ex_310/lib/python3.10/site-packages/smt/applications/mixed_integer.py:279, in MixedIntegerKrigingModel.predict_values(self, x, is_acting)
#     277 def predict_values(self, x: np.ndarray, is_acting=None) -> np.ndarray:
#     278     x_corr, is_acting = self._get_x_for_surrogate_model(np.copy(x))
# --> 279     return self._surrogate.predict_values(x_corr, is_acting=is_acting)
#
# File ~/miniconda3/envs/smt_ex_310/lib/python3.10/site-packages/smt/surrogate_models/krg_based.py:1649, in KrgBased.predict_values(self, x, is_acting)
#    1647 # Evaluate the unknown points using the specified model-method
#    1648 with self.printer._timed_context("Predicting", key="prediction"):
# -> 1649     y = self._predict_values(x2, is_acting=is_acting)
#    1650 time_pt = self.printer._time("prediction")[-1] / n
#    1651 self.printer()
#
# File ~/miniconda3/envs/smt_ex_310/lib/python3.10/site-packages/smt/surrogate_models/krg_based.py:1675, in KrgBased._predict_values(self, x, is_acting)
#    1673 if not (self.is_continuous):
#    1674     x, is_acting, n_eval, ij, Lij, dx = self._predict_init(x, is_acting)
# -> 1675     r = self._matrix_data_corr(
#    1676         corr=self.options["corr"],
#    1677         design_space=self.design_space,
#    1678         power=self.options["pow_exp_power"],
#    1679         theta=self.optimal_theta,
#    1680         theta_bounds=self.options["theta_bounds"],
#    1681         dx=dx,
#    1682         Lij=Lij,
#    1683         n_levels=self.n_levels,
#    1684         cat_features=self.cat_features,
#    1685         cat_kernel=self.options["categorical_kernel"],
#    1686         x=x,
#    1687         kplsk_second_loop=self.kplsk_second_loop,
#    1688     ).reshape(n_eval, self.nt)
#    1690     X_cont, _ = compute_X_cont(x, self.design_space)
#    1692 else:
#
# File ~/miniconda3/envs/smt_ex_310/lib/python3.10/site-packages/smt/surrogate_models/krg_based.py:859, in KrgBased._matrix_data_corr(self, corr, design_space, power, theta, theta_bounds, dx, Lij, n_levels, cat_features, cat_kernel, x, kplsk_second_loop)
#     857     x_icat = x_icat[:, i]
#     858     x_full_space = compute_X_cross(x_icat, self.n_levels_origin[i])
# --> 859     dx_cat_i = cross_levels_homo_space(
#     860         x_full_space, self.ij, y=X_full_space
#     861     )
#     862 else:
#     863     dx_cat_i = cross_levels_homo_space(X_full_space, self.ij)
#
# File ~/miniconda3/envs/smt_ex_310/lib/python3.10/site-packages/smt/utils/kriging.py:207, in cross_levels_homo_space(X, ij, y)
#     205         dx[ll] = X[i] * X[j]
#     206     else:
# --> 207         dx[ll] = X[i] * y[j]
#     209 return dx
#
# KeyboardInterrupt:

# %%
# %%time
model = gtm
features = [(0, 1), (1, 2)]

gt_pdd_2d = PartialDependenceDisplay.from_surrogate_model(
    model, 
    X, 
    features, 
    categorical_feature_indices=categorical_feature_indices, 
    feature_names=feature_names,
    grid_resolution=10,
    kind='both',
    categories_map=categories_map,
    )

gt_pdd_2d.plot(centered=True, figsize=[20, 5])
# Out:
# CPU times: user 65.5 ms, sys: 11.7 ms, total: 77.2 ms
# Wall time: 78.5 ms

# %%
# %%time
model = sm
features = [(0, 1), (1, 2)]

pdd_2d = PartialDependenceDisplay.from_surrogate_model(
    model, 
    X, 
    features, 
    categorical_feature_indices=categorical_feature_indices, 
    feature_names=feature_names,
    grid_resolution=10,
    kind='both',
    categories_map=categories_map,
    )

pdd_2d.plot(centered=True, figsize=[20, 5])
# Out:
# CPU times: user 5min 5s, sys: 7min 12s, total: 12min 18s
# Wall time: 1min 47s
